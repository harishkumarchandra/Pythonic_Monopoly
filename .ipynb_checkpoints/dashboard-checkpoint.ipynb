# %% [markdown]
# # San Francisco Rental Prices Dashboard
#
# In this notebook, you will compile the visualizations from the previous analysis into functions that can be used for a Panel dashboard.

# %%
# imports
import panel as pn
pn.extension('plotly')
import plotly.express as px
import pandas as pd
import hvplot.pandas
import matplotlib.pyplot as plt
import os
from pathlib import Path
from dotenv import load_dotenv

# %%
# Read the Mapbox API key
load_dotenv()
mapbox_token = os.getenv("MAPBOX_API_KEY")

# %% [markdown]
# # Import Data

# %%
# Import the CSVs to Pandas DataFrames
file_path = Path("Data/sfo_neighborhoods_census_data.csv")
sfo_data = pd.read_csv(file_path, index_col="year")

file_path = Path("Data/neighborhoods_coordinates.csv")
df_neighborhood_locations = pd.read_csv(file_path)

# %% [markdown]
# - - -

# %% [markdown]
# ## Panel Visualizations
#
# In this section, you will copy the code for each plot type from your analysis notebook and place it into separate functions that Panel can use to create panes for the dashboard.
#
# These functions will convert the plot object to a Panel pane.
#
# Be sure to include any DataFrame transformation/manipulation code required along with the plotting code.
#
# Return a Panel pane object from each function that can be used to build the dashboard.
#
# Note: Remove any `.show()` lines from the code. We want to return the plots instead of showing them. The Panel dashboard will then display the plots.

# %%
# Define Panel Visualization Functions
def housing_units_per_year():
    """Housing Units Per Year."""
    
    # YOUR CODE HERE!
    fig_housing_units = sfo_data['housing_units'].groupby('year').mean()
    return fig_housing_units.hvplot.bar(x='year',y='housing_units',ylim=[fig_housing_units.min(),fig_housing_units.max()])

def average_gross_rent():
    """Average Gross Rent in San Francisco Per Year."""
    
    # YOUR CODE HERE!
    average_gross_rent_and_average_sales_price = sfo_data[['sale_price_sqr_foot','gross_rent']].groupby('year').mean()
    return average_gross_rent_and_average_sales_price['gross_rent'].hvplot.line(x='year',y='gross_rent')

def average_sales_price():
    """Average Sales Price Per Year."""
    
    # YOUR CODE HERE!
    average_gross_rent_and_average_sales_price = sfo_data[['sale_price_sqr_foot','gross_rent']].groupby('year').mean()
    return average_gross_rent_and_average_sales_price['sale_price_sqr_foot'].hvplot.line(x='year',y='sale_price_sqr_foot')

def average_price_by_neighborhood(neighborhood):
    """Average Prices by Neighborhood."""
    
    # YOUR CODE HERE!
    Average_Prices_by_Neighborhood = sfo_data.groupby(['year','neighborhood']).mean()
    Average_Prices_by_Neighborhood = Average_Prices_by_Neighborhood.reset_index()
    df = Average_Prices_by_Neighborhood.loc[Average_Prices_by_Neighborhood.neighborhood == neighborhood]
    return df[['year','sale_price_sqr_foot']].hvplot.line(x='year',y='sale_price_sqr_foot')

def top_most_expensive_neighborhoods():
    """Top 10 Most Expensive Neighborhoods."""
    
    # YOUR CODE HERE!
    df_expsive = sfo_data.groupby(['neighborhood']).mean().sort_values("sale_price_sqr_foot", ascending=False).head(10).reset_index()
    df_expsive_bar = df_expsive[['neighborhood','sale_price_sqr_foot']]
    return df_expsive_bar.hvplot.bar(x='neighborhood',y='sale_price_sqr_foot',rot=90,ylim=(1000, 600))

def parallel_coordinates():
    """Parallel Coordinates Plot."""
    
    # YOUR CODE HERE!
    df_expsive = sfo_data.groupby(['neighborhood']).mean().sort_values("sale_price_sqr_foot", ascending=False).head(10).reset_index()
    return px.parallel_coordinates(df_expsive[['sale_price_sqr_foot','housing_units','gross_rent']], color='sale_price_sqr_foot')

def parallel_categories():
    """Parallel Categories Plot."""
    
    # YOUR CODE HERE!
    df_expsive = sfo_data.groupby(['neighborhood']).mean().sort_values("sale_price_sqr_foot", ascending=False).head(10).reset_index()
    return px.parallel_categories(df_expsive,color='sale_price_sqr_foot')

def neighborhood_map():
    """Neighborhood Map"""
    
    # YOUR CODE HERE!
    
    n_mean = sfo_data.groupby('neighborhood').mean().reset_index().drop(columns='neighborhood')
    mapbox_data = pd.concat([n_mean, df_neighborhood_locations], axis=1)
    px.set_mapbox_access_token(mapbox_token)
    return px.scatter_mapbox(
        mapbox_data,
        lat="Lat",
        lon="Lon",
        size="sale_price_sqr_foot",
        color="gross_rent",
        zoom=10
    )

# %% [markdown]
# ## Panel Dashboard
#
# In this section, you will combine all of the plots into a single dashboard view using Panel. Be creative with your dashboard design!

# %%
# YOUR CODE HERE!
from panel.interact import interact
row = pn.Row(housing_units_per_year, average_gross_rent, average_sales_price)

column1 = pn.Column(
    interact(average_price_by_neighborhood, neighborhood = sfo_data.neighborhood),
    top_most_expensive_neighborhoods
)

column2 = pn.Column(
    parallel_coordinates,
    parallel_categories
)

tabs = pn.Tabs(
    ("welcome", neighborhood_map),
    ("Yearly Market Analysis",row),
    ("Neighborhood Analysis",column1),
    ("Parallel Plots Analysis", column2))

# %% [markdown]
# ## Serve the Panel Dashboard

# %%
tabs.servable()
# Out:
# Tabs
#     [0] Column
#         [0] Column()
#         [1] Row
#             [0] Plotly(Figure, name='interactive06007')
#     [1] Row
#         [0] Column
#             [0] Column()
#             [1] Row
#                 [0] HoloViews(Bars, name='interactive05579')
#         [1] Column
#             [0] Column()
#             [1] Row
#                 [0] HoloViews(Curve, name='interactive05661')
#         [2] Column
#             [0] Column()
#             [1] Row
#                 [0] HoloViews(Curve, name='interactive05743')
#     [2] Column
#         [0] Column
#             [0] Column
#                 [0] Select(name='neighborhood', options=['Alamo Square', ...], value='Alamo Square')
#             [1] Row
#                 [0] HoloViews(Curve, name='interactive05826')
#         [1] Column
#             [0] Column()
#             [1] Row
#                 [0] HoloViews(Bars, name='interactive05910')
#     [3] Column
#         [0] Column
#             [0] Column()
# ...
